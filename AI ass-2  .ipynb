# %%
 
#Area of Triangle :
#Given the lengths of three sides of a triangle, calculate the area of the triangle. 
 
a=int(input ("enter the first side of triangle :"))
b=int(input ("enter the second side of triangle :"))
c=int(input ("enter the third side of triangle :"))
s=(a+b+c)/2
area=(s*(s-a)*(s-b)*(s-c))**(1/2)
print ("area=",area)
# Out:
# enter the first side of triangle :12
# enter the second side of triangle :15
# enter the third side of triangle :18
# area= 89.29410674842993

# %%
 
#Take a string from end user and check if the value is palindrome or not
 
def isPalindrome (s):
    return s==s[::-1]
s=input("enter the string:")
ans=isPalindrome(s)
if ans:
   print("palindrome")
else:
   print("Not palindrome")
# Out:
# enter the string:mom
# palindrome

# %%
#Write a program that reads a year from the user and displays a message 
#Indicating whether or not it is a leap year.
 
year=int(input("enter the year:"))
if (year%400==0):
   print("%d is a leap year" %year)
elif (year%100==0):
   print("%d is not a leap year" %year)
elif (year%4==0):
   print("%d is a leap year" %year)
else:
   print("%d is not a leap year" %year)
# Out:
# enter the year:2000
# 2000 is a leap year

# %%
#Space To Hyphen problem 
#Take a string as input, and replaces spaces “ “  with hyphens “-”, and returns a string.
#Input: “ This program converts spaces into hyphen”
#Output:“ This-program-converts-spaces-into-hyphen”
 
str1=input (" enter the string:")
str2=str1.replace(' ','_')
print("str2:",str2)
# Out:
#  enter the string:This program converts spaces into hyphen
# str2: This_program_converts_spaces_into_hyphen

# %%
#Unique Sort problem 
#Take a string as input that accepts a comma separated sequence of words as input and prints the unique words in sorted form (alphanumerically).
#*Input*: orange, white, red, cyan, green, magenta, cyan, pink, white
#*Output*: cyan, green, magenta, orange, pink, red, white
 
items = input("input comma separated sequence of words ")
words=[word for word in items.split(",")]
print(",".join(sorted(list(set(words)))))
# Out:
# input comma separated sequence of words red,black,pink,green
# black,green,pink,red

# %%
#Tax Calculator
#Ask the user for their monthly salary. Calculate whether they have to pay tax and if so, how much is that amount .Print the result
 
salary=int(input("enter monthly salary:"))
if (salary <=250000):
  tax=0
  print("total amount:",tax)
elif (250001<=salary <=500000):
  tax=((salary-250001)*(5/100))
  print("total amount:",tax)
elif (500001<=salary <=750000): 
  tax=((salary-500001)*(10/100))
  print("total amount:",tax)
elif (750001<=salary <=1000000):
  tax=((salary-750001)*(15/100))
  print("total amount:",tax)
elif (1000001<=salary <=1250000):
  tax=((salary-1000001)*(20/100))
  print("total amount:",tax)
elif (1250001<=salary <=1500000):  
  tax=((salary-1250001)*(25/100))
  print("total amount:",tax)
else:
  tax=((salary-1500000)*(30/100))
  print("total amount:",tax)
# Out:
# enter monthly salary:1250000
# total amount: 49999.8

# %%
#Take a list of integers as an argument, and converts it into a single integer (return the integer).
#*Input*: [11, 33, 50]
#*Output*: 113350
 
def convert(list):
    s=[str(i) for i in list]
    res=int("".join(s))
    return(res)

# %%
list=[11,33,50]
print(convert(list))
# Out:
# 113350

# %%
#Units of Time
#Create a program that reads duration from the user as a number of days, hours, minutes, and seconds. Compute and display the total number of seconds represented by this duration.
 
days=int(input("enter days:"))*3600*24
hrs=int(input("enter hrs:"))*3600
mins=int(input("enter mins:"))*60
secs=int(input("enter secs:"))
Totalsecs=days+hrs+mins+secs
print("Total seconds in this duration:",Totalsecs)
# Out:
# enter days:2
# enter hrs:24
# enter mins:60
# enter secs:45
# Total seconds in this duration: 262845

# %%
#Sort 3 Integers
#Given three integers (given through user input), sort the numbers using |min| and  |max| functions.
 
x=int(input("enter the first number:"))
y=int(input("enter the second number:"))
z=int(input("enter the third number:"))
a1=min(x,y,z)
a3=max(x,y,z)
a2=(x+y+z)-a1-a3
print("three integers are:",a1,a2,a3)
# Out:
# enter the first number:1
# enter the second number:4
# enter the third number:3
# three integers are: 1 3 4

# %%
#Write a program that reads a date from the user and computes its immediate successor. The date is the format YYYY-MM-DD. So, 2020-04-15 will have the successor 2020-04-16.
 
year = int(input("Input a year: "))
 
if (year % 400 == 0):
    leap_year = True
elif (year % 100 == 0):
    leap_year = False
elif (year % 4 == 0):
    leap_year = True
else:
    leap_year = False
 
month = int(input("Input a month [1-12]: "))
 
if month in (1, 3, 5, 7, 8, 10, 12):
    month_length = 31
elif month == 2:
    if leap_year:
        month_length = 29
    else:
        month_length = 28
else:
    month_length = 30
 
 
day = int(input("Input a day [1-31]: "))
 
if day < month_length:
    day += 1
else:
    day = 1
    if month == 12:
        month = 1
        year += 1
    else:
        month += 1
print("The next date is [yyyy-mm-dd] %d-%d-%d." % (year, month, day))
# Out:
# Input a year: 1978
# Input a month [1-12]: 2
# Input a day [1-31]: 28
# The next date is [yyyy-mm-dd] 1978-3-1.

# %%
#Compute product of a list of numbers [45 ,3,2,89,72,1,10,7]
#Output: 121111200
 
from functools import reduce 
list=[45,3,2,89,72,1,10,7]
result=reduce ((lambda x,y:x*y),list)
print ("result =",result)
# Out:
# result = 121111200

# %%
#Compute given Num_list =  [5, 6,8 ,34,89,1] to get desired output
#Output: Out_list=[11,14,42,123,90]
 
numlist=[5,6,8,34,89,1]
print(" The original list:"+str(numlist))
res = [numlist[i]+numlist[i+1] for i in range (len(numlist) - 1)]
print(" The computed successive product list is :"+str(res))
# Out:
#  The original list:[5, 6, 8, 34, 89, 1]
#  The computed successive product list is :[11, 14, 42, 123, 90]

# %%
#Compute given Num_tuple =  (5, 6,8 ,3,9,1) to get desired output
#Output: Out_list = [5, 30, 240, 720, 6480, 6480]
 
input = [(1,5),(5,6),(30,8),(240,3),(720,9),(6480,1)]
output =[]
for elem in input :
    temp = elem[0]*elem[1]
    output. append(temp)
print("The output  list of tuple ")
print(output)
# Out:
# The output  list of tuple
# [5, 30, 240, 720, 6480, 6480]

# %%
#Write a Python code that takes a number and returns a list of its digits. So for 586392 it should return [5,8,6,3,9,2]
 
input_number= input("enter the number:")
c=str(input_number)
int_list=[]
for i in range(len(c)):
    int_list.append(int(c[i]))
print(int_list)
# Out:
# enter the number:456823
# [4, 5, 6, 8, 2, 3]

# %%
#Write a program that finds the longest palindromic substring of a given string
 
class solution(object):
     def longestpalindrome(self,s):
         dp=[[False for i in range(len(s))] for i in range(len(s))]
         for i in range(len(s)):
             dp[i][i]=True 
         maxlength=1
         start=0
         for l in range(2,len(s)+1):
            for i in range(len(s)-l+1):
               end=i+l
               if l==2:
                 if s[i]==s[end-1]:
                    dp[i][end-1]=True 
                    maxlength=l
                    start=i
               else:
                 if s[i]==s[end-1] and dp[i+1][end-2]:
                        dp[i][end-1]=True 
                        maxlength=l 
                        start=i 
         return s[start:start+maxlength]
ob1=solution()
print(ob1.longestpalindrome("abbabbca"))
# Out:
# bbabb

# %%
#Substring Check (Bug Funny)
#Given two binary strings, A (of length 10) and B (of length 5), output 1 if B is a substring of A and 0 otherwise.
#First two lines of input:
 
#1010110010          10110
#1110111011           10011
#First two lines of output:
#1
#0
 
a= input ("enter the string1 :")
b= input ("enter the string2 :")
if b in a:
   print (" output is 1:")
else:
   print (" output is 0:")
# Out:
# enter the string1 :1010110010
# enter the string2 :10110
#  output is 1:

# %%
#POUR1 - Pouring water
#Given two vessels, one of which can accommodate a litres of water and the other - b litres of water, determine the number of steps required to obtain exactly c litres of water in one of the vessels.
#At the beginning both vessels are empty. The following operations are counted as 'steps':
#emptying a vessel,
#filling a vessel,
#pouring water from one vessel to the other, without spilling, until one of the vessels is either full or empty.
#Input
#An integer t, 1<=t<=100, denoting the number of testcases , followed by t sets of input data, each consisting of three positive integers a, b, c, not larger than 40000, given in separate lines.
#Output
#For each set of input data, output the minimum number of steps required to obtain c litres, or -1 if this is impossible.
 
def gcd(a,b):
 
    if b==0: 
 
        return a 
 
    return gcd(b,a%b) 
 
def countsteps(a,b,c): 
 
    v1=b
 
    v2=0
 
    count=1
 
    while ((v1 is not c) and (v2 is not c)): 
 
        temp=min(v1,a-v2) 
 
        v2=v2+temp 
 
        v1=v1-temp 
 
        count=count+1
 
        if ((v2==c)or(v1==c)): 
 
            break
 
        if v1==0: 
 
            v1=b 
 
            count=count+1
 
        if v2==a: 
 
            v2=0
 
            count=count+1
 
    return count 
 
def ispossible(a,b,c): 
 
    if a>b: 
 
        temp=a 
 
        a=b 
 
        b=temp 
 
    if c>b: 
 
        return -1
 
    if (c%(gcd(b,a)) is not 0): 
 
        return -1
 
    return(min(countsteps(b,a,c),countsteps(a,b,c)))
 
t=int(input("Enter no of testcases : "))
 
for i in range(t):
 
  a=int(input("Enter capacity of vessel a : "))
 
  b=int(input("Enter capacity of vessel b : "))
 
  c=int(input("Enter capacity to be obtained :"))
 
  print("Minimum number of steps required is : ",ispossible(a,b,c))
# Out:
# Enter no of testcases : 1
# Enter capacity of vessel a : 3
# Enter capacity of vessel b : 5
# Enter capacity to be obtained :9
# Minimum number of steps required is :  -1
